# %% [markdown]
# # Manejo de datos faltantes

# %% [markdown]
# Un fenomeno recurrente que ocurre con los datos del "mundo real" es que hayan algunas filas con valores faltantes.
#
# Es muy importante dentro del procesamiento de los datos
# 1. Identificar los valores faltantes
# 2. Entender el por qué de estos valores faltantes
# 3. Decidir qué hacer con ellos

# %%
import pandas as pd

# %% [markdown]
# Vamos a experimentar con un dataset (https://www.kaggle.com/datasets/altruistdelhite04/loan-prediction-problem-dataset)

# %%
data = pd.read_csv("LoanPrediction.csv")

# %%
data.describe(include='all')
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP001673   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
# mean         NaN    NaN     NaN        NaN       NaN           NaN
# std          NaN    NaN     NaN        NaN       NaN           NaN
# min          NaN    NaN     NaN        NaN       NaN           NaN
# 25%          NaN    NaN     NaN        NaN       NaN           NaN
# 50%          NaN    NaN     NaN        NaN       NaN           NaN
# 75%          NaN    NaN     NaN        NaN       NaN           NaN
# max          NaN    NaN     NaN        NaN       NaN           NaN
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        614.000000         614.000000  592.000000         600.00000
# unique              NaN                NaN         NaN               NaN
# top                 NaN                NaN         NaN               NaN
# freq                NaN                NaN         NaN               NaN
# mean        5403.459283        1621.245798  146.412162         342.00000
# std         6109.041673        2926.248369   85.587325          65.12041
# min          150.000000           0.000000    9.000000          12.00000
# 25%         2877.500000           0.000000  100.000000         360.00000
# 50%         3812.500000        1188.500000  128.000000         360.00000
# 75%         5795.000000        2297.250000  168.000000         360.00000
# max        81000.000000       41667.000000  700.000000         480.00000
#
#         Credit_History Property_Area Loan_Status
# count       564.000000           614         614
# unique             NaN             3           2
# top                NaN     Semiurban           Y
# freq               NaN           233         422
# mean          0.842199           NaN         NaN
# std           0.364878           NaN         NaN
# min           0.000000           NaN         NaN
# 25%           1.000000           NaN         NaN
# 50%           1.000000           NaN         NaN
# 75%           1.000000           NaN         NaN
# max           1.000000           NaN         NaN

# %% [markdown]
# Podemos ver facilmente la cantidad de valores nulos con el siguiente comando:

# %%
data.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# Las columnas con mas missing values con Credit History, Self employed y LoanAmount.

# %% [markdown]
# # Eliminar datos faltantes

# %% [markdown]
# Para eliminar datos faltantes utilizaremos el metodo ```.dropna()``` de pandas.

# %% [markdown]
# ## Eliminar las columnas con datos faltantes

# %%
# Un comando simple que nos permite eliminar todas las columnas donde haya uno o mas datos faltantes

data_noMS_col = data.dropna(axis=1)

# %%
data_noMS_col.describe(include='all')
# Out:
#          Loan_ID Education  ApplicantIncome  CoapplicantIncome Property_Area  \
# count        614       614       614.000000         614.000000           614
# unique       614         2              NaN                NaN             3
# top     LP001673  Graduate              NaN                NaN     Semiurban
# freq           1       480              NaN                NaN           233
# mean         NaN       NaN      5403.459283        1621.245798           NaN
# std          NaN       NaN      6109.041673        2926.248369           NaN
# min          NaN       NaN       150.000000           0.000000           NaN
# 25%          NaN       NaN      2877.500000           0.000000           NaN
# 50%          NaN       NaN      3812.500000        1188.500000           NaN
# 75%          NaN       NaN      5795.000000        2297.250000           NaN
# max          NaN       NaN     81000.000000       41667.000000           NaN
#
#        Loan_Status
# count          614
# unique           2
# top              Y
# freq           422
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %% [markdown]
# Tambien podemos setear un umbral y eliminar todas las columnas con cierto porcentaje de datos faltantes. Por ejemplo: eliminemos las columnas que tienen 10% o mas datos faltantes.

# %%
data_noMS_col_10 = data.dropna(axis=1, thresh=0.95*len(data))

# %%
data_noMS_col_10.describe(include='all')
# Out:
#          Loan_ID Gender Married Dependents Education  ApplicantIncome  \
# count        614    601     611        599       614       614.000000
# unique       614      2       2          4         2              NaN
# top     LP001673   Male     Yes          0  Graduate              NaN
# freq           1    489     398        345       480              NaN
# mean         NaN    NaN     NaN        NaN       NaN      5403.459283
# std          NaN    NaN     NaN        NaN       NaN      6109.041673
# min          NaN    NaN     NaN        NaN       NaN       150.000000
# 25%          NaN    NaN     NaN        NaN       NaN      2877.500000
# 50%          NaN    NaN     NaN        NaN       NaN      3812.500000
# 75%          NaN    NaN     NaN        NaN       NaN      5795.000000
# max          NaN    NaN     NaN        NaN       NaN     81000.000000
#
#         CoapplicantIncome  LoanAmount  Loan_Amount_Term Property_Area  \
# count          614.000000  592.000000         600.00000           614
# unique                NaN         NaN               NaN             3
# top                   NaN         NaN               NaN     Semiurban
# freq                  NaN         NaN               NaN           233
# mean          1621.245798  146.412162         342.00000           NaN
# std           2926.248369   85.587325          65.12041           NaN
# min              0.000000    9.000000          12.00000           NaN
# 25%              0.000000  100.000000         360.00000           NaN
# 50%           1188.500000  128.000000         360.00000           NaN
# 75%           2297.250000  168.000000         360.00000           NaN
# max          41667.000000  700.000000         480.00000           NaN
#
#        Loan_Status
# count          614
# unique           2
# top              Y
# freq           422
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %%
data.describe(include="all")
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP001673   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
# mean         NaN    NaN     NaN        NaN       NaN           NaN
# std          NaN    NaN     NaN        NaN       NaN           NaN
# min          NaN    NaN     NaN        NaN       NaN           NaN
# 25%          NaN    NaN     NaN        NaN       NaN           NaN
# 50%          NaN    NaN     NaN        NaN       NaN           NaN
# 75%          NaN    NaN     NaN        NaN       NaN           NaN
# max          NaN    NaN     NaN        NaN       NaN           NaN
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        614.000000         614.000000  592.000000         600.00000
# unique              NaN                NaN         NaN               NaN
# top                 NaN                NaN         NaN               NaN
# freq                NaN                NaN         NaN               NaN
# mean        5403.459283        1621.245798  146.412162         342.00000
# std         6109.041673        2926.248369   85.587325          65.12041
# min          150.000000           0.000000    9.000000          12.00000
# 25%         2877.500000           0.000000  100.000000         360.00000
# 50%         3812.500000        1188.500000  128.000000         360.00000
# 75%         5795.000000        2297.250000  168.000000         360.00000
# max        81000.000000       41667.000000  700.000000         480.00000
#
#         Credit_History Property_Area Loan_Status
# count       564.000000           614         614
# unique             NaN             3           2
# top                NaN     Semiurban           Y
# freq               NaN           233         422
# mean          0.842199           NaN         NaN
# std           0.364878           NaN         NaN
# min           0.000000           NaN         NaN
# 25%           1.000000           NaN         NaN
# 50%           1.000000           NaN         NaN
# 75%           1.000000           NaN         NaN
# max           1.000000           NaN         NaN

# %% [markdown]
# Finalmente, como vimos en clases anteriores, podemos eliminar una columna particular

# %%
data1 = data.drop(['Dependents'],axis=1)

# %%
data1
# Out:
#       Loan_ID  Gender Married     Education Self_Employed  ApplicantIncome  \
# 0    LP001002    Male      No      Graduate            No             5849
# 1    LP001003    Male     Yes      Graduate            No             4583
# 2    LP001005    Male     Yes      Graduate           Yes             3000
# 3    LP001006    Male     Yes  Not Graduate            No             2583
# 4    LP001008    Male      No      Graduate            No             6000
# ..        ...     ...     ...           ...           ...              ...
# 609  LP002978  Female      No      Graduate            No             2900
# 610  LP002979    Male     Yes      Graduate            No             4106
# 611  LP002983    Male     Yes      Graduate            No             8072
# 612  LP002984    Male     Yes      Graduate            No             7583
# 613  LP002990  Female      No      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0         NaN             360.0             1.0
# 1               1508.0       128.0             360.0             1.0
# 2                  0.0        66.0             360.0             1.0
# 3               2358.0       120.0             360.0             1.0
# 4                  0.0       141.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 609                0.0        71.0             360.0             1.0
# 610                0.0        40.0             180.0             1.0
# 611              240.0       253.0             360.0             1.0
# 612                0.0       187.0             360.0             1.0
# 613                0.0       133.0             360.0             0.0
#
#     Property_Area Loan_Status
# 0           Urban           Y
# 1           Rural           N
# 2           Urban           Y
# 3           Urban           Y
# 4           Urban           Y
# ..            ...         ...
# 609         Rural           Y
# 610         Rural           Y
# 611         Urban           Y
# 612         Urban           Y
# 613     Semiurban           N
#
# [614 rows x 12 columns]

# %% [markdown]
# ## Eliminar las filas con datos faltantes

# %% [markdown]
# Eliminar todas las filas con valores faltantes

# %%
data_noMS = data.dropna(axis=0)

# %%
data_noMS.describe(include="all")
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        480    480     480        480       480           480
# unique       480      2       2          4         2             2
# top     LP001640   Male     Yes          0  Graduate            No
# freq           1    394     311        274       383           414
# mean         NaN    NaN     NaN        NaN       NaN           NaN
# std          NaN    NaN     NaN        NaN       NaN           NaN
# min          NaN    NaN     NaN        NaN       NaN           NaN
# 25%          NaN    NaN     NaN        NaN       NaN           NaN
# 50%          NaN    NaN     NaN        NaN       NaN           NaN
# 75%          NaN    NaN     NaN        NaN       NaN           NaN
# max          NaN    NaN     NaN        NaN       NaN           NaN
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        480.000000         480.000000  480.000000        480.000000
# unique              NaN                NaN         NaN               NaN
# top                 NaN                NaN         NaN               NaN
# freq                NaN                NaN         NaN               NaN
# mean        5364.231250        1581.093583  144.735417        342.050000
# std         5668.251251        2617.692267   80.508164         65.212401
# min          150.000000           0.000000    9.000000         36.000000
# 25%         2898.750000           0.000000  100.000000        360.000000
# 50%         3859.000000        1084.500000  128.000000        360.000000
# 75%         5852.500000        2253.250000  170.000000        360.000000
# max        81000.000000       33837.000000  600.000000        480.000000
#
#         Credit_History Property_Area Loan_Status
# count       480.000000           480         480
# unique             NaN             3           2
# top                NaN     Semiurban           Y
# freq               NaN           191         332
# mean          0.854167           NaN         NaN
# std           0.353307           NaN         NaN
# min           0.000000           NaN         NaN
# 25%           1.000000           NaN         NaN
# 50%           1.000000           NaN         NaN
# 75%           1.000000           NaN         NaN
# max           1.000000           NaN         NaN

# %% [markdown]
# Eliminar las filas donde falten mas de 2 valores

# %%
len(data.columns)
# Out:
# 13

# %%
data_noMS_5 = data.dropna(axis=0, thresh=11)

# %%
data_noMS_5.describe(include='all')
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        612    599     610        598       612           581
# unique       612      2       2          4         2             2
# top     LP001673   Male     Yes          0  Graduate            No
# freq           1    488     398        344       478           499
# mean         NaN    NaN     NaN        NaN       NaN           NaN
# std          NaN    NaN     NaN        NaN       NaN           NaN
# min          NaN    NaN     NaN        NaN       NaN           NaN
# 25%          NaN    NaN     NaN        NaN       NaN           NaN
# 50%          NaN    NaN     NaN        NaN       NaN           NaN
# 75%          NaN    NaN     NaN        NaN       NaN           NaN
# max          NaN    NaN     NaN        NaN       NaN           NaN
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        612.000000         612.000000  592.000000        598.000000
# unique              NaN                NaN         NaN               NaN
# top                 NaN                NaN         NaN               NaN
# freq                NaN                NaN         NaN               NaN
# mean        5393.619281        1626.543987  146.412162        342.140468
# std         6115.885392        2929.560873   85.587325         65.091357
# min          150.000000           0.000000    9.000000         12.000000
# 25%         2875.750000           0.000000  100.000000        360.000000
# 50%         3806.000000        1211.500000  128.000000        360.000000
# 75%         5754.500000        2303.000000  168.000000        360.000000
# max        81000.000000       41667.000000  700.000000        480.000000
#
#         Credit_History Property_Area Loan_Status
# count       563.000000           612         612
# unique             NaN             3           2
# top                NaN     Semiurban           Y
# freq               NaN           232         421
# mean          0.841918           NaN         NaN
# std           0.365142           NaN         NaN
# min           0.000000           NaN         NaN
# 25%           1.000000           NaN         NaN
# 50%           1.000000           NaN         NaN
# 75%           1.000000           NaN         NaN
# max           1.000000           NaN         NaN

# %% [markdown]
# Eliminar las filas donde falte uno o mas valores particulares

# %%
# eliminamos las filas sin Gender

data_noMS_Gender = data.dropna(axis=0, subset=['Gender'])

# %%
data_noMS_Gender.describe(include='all')
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        601    601     598        586       601           569
# unique       601      2       2          4         2             2
# top     LP001640   Male     Yes          0  Graduate            No
# freq           1    489     388        338       468           491
# mean         NaN    NaN     NaN        NaN       NaN           NaN
# std          NaN    NaN     NaN        NaN       NaN           NaN
# min          NaN    NaN     NaN        NaN       NaN           NaN
# 25%          NaN    NaN     NaN        NaN       NaN           NaN
# 50%          NaN    NaN     NaN        NaN       NaN           NaN
# 75%          NaN    NaN     NaN        NaN       NaN           NaN
# max          NaN    NaN     NaN        NaN       NaN           NaN
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        601.000000         601.000000  579.000000        587.000000
# unique              NaN                NaN         NaN               NaN
# top                 NaN                NaN         NaN               NaN
# freq                NaN                NaN         NaN               NaN
# mean        5296.818636        1624.610516  145.017271        342.010221
# std         5796.332957        2947.638410   82.565103         65.428333
# min          150.000000           0.000000    9.000000         12.000000
# 25%         2882.000000           0.000000  100.000000        360.000000
# 50%         3813.000000        1167.000000  127.000000        360.000000
# 75%         5746.000000        2306.000000  166.500000        360.000000
# max        81000.000000       41667.000000  650.000000        480.000000
#
#         Credit_History Property_Area Loan_Status
# count       552.000000           601         601
# unique             NaN             3           2
# top                NaN     Semiurban           Y
# freq               NaN           227         414
# mean          0.844203           NaN         NaN
# std           0.362992           NaN         NaN
# min           0.000000           NaN         NaN
# 25%           1.000000           NaN         NaN
# 50%           1.000000           NaN         NaN
# 75%           1.000000           NaN         NaN
# max           1.000000           NaN         NaN

# %%
# eliminar las filas sin Gender o sin Self_Employed

data_noMS_Gender_SE = data.dropna(axis=0, subset=['Gender', 'Self_Employed'])

# %%
data_noMS_Gender_SE.describe(include='all')
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        569    569     566        554       569           569
# unique       569      2       2          4         2             2
# top     LP001640   Male     Yes          0  Graduate            No
# freq           1    465     370        319       442           491
# mean         NaN    NaN     NaN        NaN       NaN           NaN
# std          NaN    NaN     NaN        NaN       NaN           NaN
# min          NaN    NaN     NaN        NaN       NaN           NaN
# 25%          NaN    NaN     NaN        NaN       NaN           NaN
# 50%          NaN    NaN     NaN        NaN       NaN           NaN
# 75%          NaN    NaN     NaN        NaN       NaN           NaN
# max          NaN    NaN     NaN        NaN       NaN           NaN
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        569.000000         569.000000  548.000000        556.000000
# unique              NaN                NaN         NaN               NaN
# top                 NaN                NaN         NaN               NaN
# freq                NaN                NaN         NaN               NaN
# mean        5264.964851        1572.145729  144.525547        342.302158
# std         5402.701885        2502.598633   81.737269         65.688498
# min          150.000000           0.000000    9.000000         12.000000
# 25%         2882.000000           0.000000  100.000000        360.000000
# 50%         3846.000000        1126.000000  127.500000        360.000000
# 75%         5815.000000        2283.000000  168.500000        360.000000
# max        81000.000000       33837.000000  650.000000        480.000000
#
#         Credit_History Property_Area Loan_Status
# count       526.000000           569         569
# unique             NaN             3           2
# top                NaN     Semiurban           Y
# freq               NaN           217         391
# mean          0.838403           NaN         NaN
# std           0.368431           NaN         NaN
# min           0.000000           NaN         NaN
# 25%           1.000000           NaN         NaN
# 50%           1.000000           NaN         NaN
# 75%           1.000000           NaN         NaN
# max           1.000000           NaN         NaN

# %%
# eliminar las filas sin Gender y Self_Employed

data_noMS_Gender_or_SE = data.dropna(axis=0, subset=['Gender', 'Self_Employed'], how='all')

# %%
data_noMS_Gender_or_SE.describe(include='all')
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP001673   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
# mean         NaN    NaN     NaN        NaN       NaN           NaN
# std          NaN    NaN     NaN        NaN       NaN           NaN
# min          NaN    NaN     NaN        NaN       NaN           NaN
# 25%          NaN    NaN     NaN        NaN       NaN           NaN
# 50%          NaN    NaN     NaN        NaN       NaN           NaN
# 75%          NaN    NaN     NaN        NaN       NaN           NaN
# max          NaN    NaN     NaN        NaN       NaN           NaN
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        614.000000         614.000000  592.000000         600.00000
# unique              NaN                NaN         NaN               NaN
# top                 NaN                NaN         NaN               NaN
# freq                NaN                NaN         NaN               NaN
# mean        5403.459283        1621.245798  146.412162         342.00000
# std         6109.041673        2926.248369   85.587325          65.12041
# min          150.000000           0.000000    9.000000          12.00000
# 25%         2877.500000           0.000000  100.000000         360.00000
# 50%         3812.500000        1188.500000  128.000000         360.00000
# 75%         5795.000000        2297.250000  168.000000         360.00000
# max        81000.000000       41667.000000  700.000000         480.00000
#
#         Credit_History Property_Area Loan_Status
# count       564.000000           614         614
# unique             NaN             3           2
# top                NaN     Semiurban           Y
# freq               NaN           233         422
# mean          0.842199           NaN         NaN
# std           0.364878           NaN         NaN
# min           0.000000           NaN         NaN
# 25%           1.000000           NaN         NaN
# 50%           1.000000           NaN         NaN
# 75%           1.000000           NaN         NaN
# max           1.000000           NaN         NaN

# %% [markdown]
# # Imputar datos faltantes

# %% [markdown]
# ## Con un valor especifico

# %%
data['Gender'] = data['Gender'].fillna('Non Specified')
# Out:
# count      614
# unique       3
# top       Male
# freq       489
# Name: Gender, dtype: object

# %% [markdown]
# ## Con la media o moda

# %%
# Media
valor_moda = data['ApplicantIncome'].mean()

data['ApplicantIncome'] = data['ApplicantIncome'].fillna(valor_moda)

data['ApplicantIncome']
# Out:
# 0      5849
# 1      4583
# 2      3000
# 3      2583
# 4      6000
#        ...
# 609    2900
# 610    4106
# 611    8072
# 612    7583
# 613    4583
# Name: ApplicantIncome, Length: 614, dtype: int64

# %%
# Moda

valor_moda = data['Self_Employed'].mode()[0]

data['Self_Employed'] = data['Self_Employed'].fillna(valor_moda)

data['Self_Employed']
# Out:
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4       No
#       ...
# 609     No
# 610     No
# 611     No
# 612     No
# 613    Yes
# Name: Self_Employed, Length: 614, dtype: object

# %% [markdown]
# Tambien podemos hacer una funcion custom que rellene los valores faltantes.
